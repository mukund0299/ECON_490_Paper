# %%
import pandas as pd
import numpy as np
import math
from geopy import distance

# %%
# https://open.canada.ca/data/en/dataset/00a331db-121b-445d-b119-35dbbe3eedd9 -- National Broadband Data
speeds = pd.read_csv("raw/PHH_Speeds_Current-PHH_Vitesses_Actuelles_BC.csv")

# Same source, map data with population information for each hex
phh = pd.read_csv("raw/PHH-BC.csv")
phhWithSpeeds = pd.merge(phh, speeds, on="PHH_ID")

# Filtering out hexes with no population
regionsWithPop = phhWithSpeeds[phhWithSpeeds["Pop2016"] > 0].copy()
regionsWithPop.columns
# Out:
# Index(['PHH_ID', 'Type', 'Pop2016', 'TDwell2016_TLog2016',
#        'URDwell2016_RH2016', 'DBUID_Ididu', 'HEXUID_IdUHEX', 'Pruid_Pridu',
#        'Latitude', 'Longitude', 'Combined_lt5_1_Combine',
#        'Wired_lt5_1_Filaire', 'Wireless_lt5_Sans_fil', 'Combined_5_1_Combine',
#        'Wired_5_1_Filaire', 'Wireless_5_1_Sans_fil', 'Combined_10_2_Combine',
#        'Wired_10_2_Filaire', 'Wireless_10_2_Sans_fil', 'Combined_25_5_Combine',
#        'Wired_25_5_Filaire', 'Wireless_25_5_Sans_fil',
#        'Combined_50_10_Combine', 'Wired_50_10_Filaire',
#        'Wireless_50_10_Sans_fil', 'Combined_Max_Threshold-Combine_Seuil_Max',
#        'Wired_Max_Threshold-Filaire_Seuil_Max',
#        'Wireless_Max_Threshold-Sans_fil_Seuil_Max', 'Avail_LTE_Mobile_Dispo'],
#       dtype='object')

# %%
school_report = pd.read_csv("combined_school_report.csv")
school_report
# Out:
#       Unnamed: 0 SCHOOL_YEAR  SCHOOL_NUMBER               SCHOOL_NAME  \
# 0              0   2019/2020         502001     Mount Baker Secondary
# 1              1   2019/2020         502001     Mount Baker Secondary
# 2              2   2019/2020         502001     Mount Baker Secondary
# 3              3   2019/2020         502001     Mount Baker Secondary
# 4              4   2019/2020         502001     Mount Baker Secondary
# ...          ...         ...            ...                       ...
# 1170        1170   2019/2020        9191024  Nechako Valley Secondary
# 1171        1171   2019/2020        9191024  Nechako Valley Secondary
# 1172        1172   2019/2020        9191024  Nechako Valley Secondary
# 1173        1173   2019/2020        9191024  Nechako Valley Secondary
# 1174        1174   2019/2020        9191024  Nechako Valley Secondary
#
#       DISTRICT_NUMBER       DISTRICT_NAME PUBLIC_OR_INDEPENDENT  \
# 0                   5  Southeast Kootenay                Public
# 1                   5  Southeast Kootenay                Public
# 2                   5  Southeast Kootenay                Public
# 3                   5  Southeast Kootenay                Public
# 4                   5  Southeast Kootenay                Public
# ...               ...                 ...                   ...
# 1170               91       Nechako Lakes                Public
# 1171               91       Nechako Lakes                Public
# 1172               91       Nechako Lakes                Public
# 1173               91       Nechako Lakes                Public
# 1174               91       Nechako Lakes                Public
#
#      STREET_ADDRESS PHYSICAL_ADDRESS_CITY  \
# 0     1410 Baker St             Cranbrook
# 1     1410 Baker St             Cranbrook
# 2     1410 Baker St             Cranbrook
# 3     1410 Baker St             Cranbrook
# 4     1410 Baker St             Cranbrook
# ...             ...                   ...
# 1170     PO Box 950            Vanderhoof
# 1171     PO Box 950            Vanderhoof
# 1172     PO Box 950            Vanderhoof
# 1173     PO Box 950            Vanderhoof
# 1174     PO Box 950            Vanderhoof
#
#                                   FACILTY_TYPE  ...    LOCATION  \
# 0     Standard School                           ...   Cranbrook
# 1     Standard School                           ...   Cranbrook
# 2     Standard School                           ...   Cranbrook
# 3     Standard School                           ...   Cranbrook
# 4     Standard School                           ...   Cranbrook
# ...                                        ...  ...         ...
# 1170  Standard School                           ...  Vanderhoof
# 1171  Standard School                           ...  Vanderhoof
# 1172  Standard School                           ...  Vanderhoof
# 1173  Standard School                           ...  Vanderhoof
# 1174  Standard School                           ...  Vanderhoof
#
#                  ENROLMENT PERCENT_ESL PERCENT_SPECIAL_NEEDS  \
# 0     Gr 12 enrolment: 257         0.4                  14.4
# 1     Gr 12 enrolment: 257         0.4                  14.4
# 2     Gr 12 enrolment: 257         0.4                  14.4
# 3     Gr 12 enrolment: 257         0.4                  14.4
# 4     Gr 12 enrolment: 257         0.4                  14.4
# ...                    ...         ...                   ...
# 1170   Gr 12 enrolment: 81         0.0                  16.6
# 1171   Gr 12 enrolment: 81         0.0                  16.6
# 1172   Gr 12 enrolment: 81         0.0                  16.6
# 1173   Gr 12 enrolment: 81         0.0                  16.6
# 1174   Gr 12 enrolment: 81         0.0                  16.6
#
#      PERCENT_FRENCH_IMM  AVERAGE_EXAM_MARK  PERCENT_EXAMS_FAILED PERCENT_GRAD  \
# 0                   6.2               66.9                   8.9         99.2
# 1                   6.2               66.4                  10.6         96.8
# 2                   6.2               66.2                   9.6         99.2
# 3                   6.2               68.0                   8.7         97.8
# 4                   6.2               66.4                   8.8         99.6
# ...                 ...                ...                   ...          ...
# 1170                4.1               66.8                  11.1         97.6
# 1171                4.1               65.6                  13.2         96.2
# 1172                4.1               67.0                  12.6         98.0
# 1173                4.1               71.7                   1.6         98.4
# 1174                4.1               66.5                   8.2         98.7
#
#       PERCENT_DELAYED OVERALL
# 0                 8.2     6.8
# 1                16.9     6.1
# 2                 5.1     6.6
# 3                 9.7     6.7
# 4                 7.3     6.7
# ...               ...     ...
# 1170              9.1     5.8
# 1171              8.3     5.1
# 1172              3.3     6.4
# 1173              7.8     6.9
# 1174              2.8     6.4
#
# [1175 rows x 29 columns]

# %%
school_representative = school_report.groupby("SCHOOL_NUMBER").first().reset_index()
regionsWithPop["DISTANCE"] = -1
regionsWithPop["SCHOOL_NUMBER"] = -1
for index, hexagon in regionsWithPop.iterrows():
    hexagon_coord = (hexagon["Latitude"], hexagon["Longitude"])
    closest_school_num = None
    closest_distance = None
    for i, school in school_representative.iterrows():
        dist = distance.distance(hexagon_coord, (school["SCHOOL_LATITUDE"], school["SCHOOL_LONGITUDE"])).km
        if (closest_distance is None or closest_distance > dist):
            closest_distance = dist
            closest_school_num = school["SCHOOL_NUMBER"]
    regionsWithPop.loc[index, "DISTANCE"] = closest_distance
    regionsWithPop.loc[index, "SCHOOL_NUMBER"] = closest_school_num

regionsWithPop.to_csv("pop_regions_with_school.csv")
regionsWithPop.groupby("SCHOOL_NUMBER").size().reset_index(name='counts')
# Out:
#      SCHOOL_NUMBER  counts
# 0           502001    4296
# 1           505033     352
# 2           505034    2180
# 3           505035     659
# 4           603008    2635
# ..             ...     ...
# 230        8585026    1821
# 231        9156002    1515
# 232        9156007    1048
# 233        9191023    1679
# 234        9191024    2133
#
# [235 rows x 2 columns]

# %%
linked = pd.read_csv("pop_regions_with_school.csv")

# Discard hexes where the closest school is over 25km away -- arbitrary assumption that students aren't traveling that far for school
discard_hex_too_far_away = linked[linked["DISTANCE"] > 25]
print("Number of hexes discarded: %d" % (linked.size - discard_hex_too_far_away.size))
discard_hex_too_far_away
# Out:
# Number of hexes discarded: 11974816
#         Unnamed: 0   PHH_ID  Type    Pop2016  TDwell2016_TLog2016  \
# 25           13004  5226091     5   6.428571             5.571429
# 26           13005  5226252     6  17.500000            24.500000
# 27           13006  5367797     5   7.000000             2.700000
# 28           13007  5367762     6  14.000000             3.500000
# 63           13049  5199801     5   4.000000             2.400000
# ...            ...      ...   ...        ...                  ...
# 420587      661349  5500964     2   0.542017             0.390756
# 420588      661350  5500965     2   0.180672             0.130252
# 420589      661351  5500966     2   5.075000             2.887500
# 420590      661353  5500968     2   4.068966             4.068966
# 420591      661354  5500969     2   7.449735             3.555556
#
#         URDwell2016_RH2016  DBUID_Ididu HEXUID_IdUHEX  Pruid_Pridu   Latitude  \
# 25                3.000000  59331492007    BC50901209           59  50.883726
# 26                9.500000  59331492084    BC50901209           59  50.883931
# 27                2.200000  59490109021    BC55171291           59  55.194293
# 28                3.500000  59490109014    BC55171291           59  55.194556
# 63                2.000000  59310142014    BC50691219           59  50.693891
# ...                    ...          ...           ...          ...        ...
# 420587            0.277311  59030243029    BC49901182           59  49.879670
# 420588            0.092437  59030243029    BC49931181           59  49.914920
# 420589            2.275000  59030137019    BC49931174           59  49.904697
# 420590            1.908046  59070135043    BC49611204           59  49.618459
# 420591            3.386243  59070302020    BC49481205           59  49.461848
#
#         ...  Wireless_25_5_Sans_fil  Combined_50_10_Combine  \
# 25      ...                       0                       0
# 26      ...                       0                       0
# 27      ...                       0                       0
# 28      ...                       0                       0
# 63      ...                       1                       0
# ...     ...                     ...                     ...
# 420587  ...                       1                       0
# 420588  ...                       0                       0
# 420589  ...                       0                       0
# 420590  ...                       0                       0
# 420591  ...                       0                       1
#
#         Wired_50_10_Filaire  Wireless_50_10_Sans_fil  \
# 25                        0                        0
# 26                        0                        0
# 27                        0                        0
# 28                        0                        0
# 63                        0                        0
# ...                     ...                      ...
# 420587                    0                        0
# 420588                    0                        0
# 420589                    0                        0
# 420590                    0                        0
# 420591                    1                        0
#
#         Combined_Max_Threshold-Combine_Seuil_Max  \
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 63                                          25_5
# ...                                          ...
# 420587                                      25_5
# 420588                                      <5_1
# 420589                                       NaN
# 420590                                      <5_1
# 420591                                     50_10
#
#         Wired_Max_Threshold-Filaire_Seuil_Max  \
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 63                                       25_5
# ...                                       ...
# 420587                                    NaN
# 420588                                    NaN
# 420589                                    NaN
# 420590                                    NaN
# 420591                                  50_10
#
#         Wireless_Max_Threshold-Sans_fil_Seuil_Max  Avail_LTE_Mobile_Dispo  \
# 25                                            NaN                       0
# 26                                            NaN                       0
# 27                                            NaN                       1
# 28                                            NaN                       1
# 63                                           25_5                       1
# ...                                           ...                     ...
# 420587                                       25_5                       1
# 420588                                       <5_1                       1
# 420589                                        NaN                       1
# 420590                                       <5_1                       0
# 420591                                        NaN                       1
#
#          DISTANCE  SCHOOL_NUMBER
# 25      45.347990        7324055
# 26      45.335320        7324055
# 27      80.264716        8288024
# 28      80.295323        8288024
# 63      73.756027        4848021
# ...           ...            ...
# 420587  66.480871         807025
# 420588  66.881717         807025
# 420589  45.302126         807013
# 420590  49.891046        6777002
# 420591  53.735826        5316004
#
# [46381 rows x 32 columns]
