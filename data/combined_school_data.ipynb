# %%
import pandas as pd
import numpy as np

# %%
#https://catalogue.data.gov.bc.ca/dataset/bc-schools-k-12-with-francophone-indicators
schools = pd.read_csv("raw/allschools_databc_20201027-fewer-columns.csv")

# Strip whitespace, map school type to match processed rows
schools["PHYSICAL_ADDRESS_CITY"] = schools["PHYSICAL_ADDRESS_CITY"].str.strip()
schools["PUBLIC_OR_INDEPENDENT"] = np.where(schools["PUBLIC_OR_INDEPENDENT"].str.contains("Public School"), "Public", "Independent")


# We are only looking at secondary schools
secondary_schools = schools[schools["SCHOOL_EDUCATION_LEVEL"].str.contains("SECONDARY")]

# Ignore non standard school types
standard_secondary = secondary_schools[secondary_schools["FACILTY_TYPE"].str.contains("Standard School")]

# Remove francophone districts
anglo_standard_secondary = standard_secondary[~standard_secondary["DISTRICT_NAME"].str.contains("Conseil scolaire francophone")]

# %%
processed_reports = pd.read_csv("processed_school_reports.csv")
# Building the mapping from one dataset to other, so just look at one year
single_year = processed_reports[processed_reports["YEAR"] == 2019]

# Assuming that if the school name from Fraser is contained in the school name from BC catalogue and the cities and type match -> Same school
merged = anglo_standard_secondary.merge(single_year, left_on=["PHYSICAL_ADDRESS_CITY", "PUBLIC_OR_INDEPENDENT"], right_on=["LOCATION", "SCHOOL_TYPE"])
filtered_merge = merged[merged.apply(lambda x: x.SCHOOL_NAME_y in x.SCHOOL_NAME_x, axis=1)]

# Need to handle duplicates, manual verification from the address
# Code below used to identify multiple schools with same name
# grouped = filtered_merge.groupby("SCHOOL_NAME_y")
# grouped = grouped.filter(lambda x: len(x) > 1)

# Dropping Abbotsford Traditional Senior Secondary 	
filtered_merge = filtered_merge[~filtered_merge["STREET_ADDRESS"].str.contains("2272 Windsor St")]
# Dropping duplicate Langley Fundamental Middle/Secondary Sch
filtered_merge = filtered_merge[~(filtered_merge["STREET_ADDRESS"].str.contains("21250 42 Ave") & (filtered_merge["SCHOOL_NAME_y"] == "Langley"))]
# Dropping Langley Equestrian Academy
filtered_merge = filtered_merge[~filtered_merge["STREET_ADDRESS"].str.contains("20902 37A Ave")]
# Drop duplicate N/S Delta
filtered_merge = filtered_merge[~(filtered_merge["STREET_ADDRESS"].str.contains("11447 82 Ave") & (filtered_merge["SCHOOL_NAME_y"] == "Delta"))]
filtered_merge = filtered_merge[~(filtered_merge["STREET_ADDRESS"].str.contains("750 53 St") & (filtered_merge["SCHOOL_NAME_y"] == "Delta"))]
# Drop Cowichan Open School
filtered_merge = filtered_merge[~filtered_merge["STREET_ADDRESS"].str.contains("1033 Nagle St")]
# Drop St John's Academy Shawnigan Lake
filtered_merge = filtered_merge[~filtered_merge["STREET_ADDRESS"].str.contains("2371 Shawnigan Lake Road")]

grouped = filtered_merge.groupby("SCHOOL_NAME_y")
grouped = grouped.filter(lambda x: len(x) > 1)
grouped
# Out:
#      SCHOOL_YEAR  SCHOOL_NUMBER                SCHOOL_NAME_x  DISTRICT_NUMBER  \
# 5      2019/2020         604015     David Thompson Secondary                6
# 581    2019/2020        3636246  Princess Margaret Secondary               36
# 1068   2019/2020        3939018     David Thompson Secondary               39
# 1995   2019/2020        6715008  Princess Margaret Secondary               67
#
#        DISTRICT_NAME PUBLIC_OR_INDEPENDENT            STREET_ADDRESS  \
# 5     Rocky Mountain                Public  1535 14th St Unit 1 RR 4
# 581           Surrey                Public              12870 72 Ave
# 1068       Vancouver                Public           1755 55th Ave E
# 1995  Okanagan Skaha                Public           120 Green Ave W
#
#      PHYSICAL_ADDRESS_CITY                              FACILTY_TYPE  \
# 5                Invermere  Standard School
# 581                 Surrey  Standard School
# 1068             Vancouver  Standard School
# 1995             Penticton  Standard School
#
#      SCHOOL_EDUCATION_LEVEL  ...   LOCATION             ENROLMENT PERCENT_ESL  \
# 5                 SECONDARY  ...  Invermere   Gr 12 enrolment: 70         0.7
# 581               SECONDARY  ...     Surrey  Gr 12 enrolment: 278        17.9
# 1068              SECONDARY  ...  Vancouver  Gr 12 enrolment: 270         8.4
# 1995              SECONDARY  ...  Penticton  Gr 12 enrolment: 113         0.0
#
#      PERCENT_SPECIAL_NEEDS  PERCENT_FRENCH_IMM  AVERAGE_EXAM_MARK  \
# 5                      8.8                 0.0               67.2
# 581                   10.4                 0.0               65.5
# 1068                   8.8                 0.0               70.0
# 1995                  14.1                 0.0               69.1
#
#      PERCENT_EXAMS_FAILED PERCENT_GRAD  PERCENT_DELAYED OVERALL
# 5                    10.5        100.0             16.8     5.9
# 581                  10.9         91.9             18.0     4.2
# 1068                  5.6         96.4             12.6     7.1
# 1995                  8.1         99.0              3.5     5.5
#
# [4 rows x 29 columns]

# %%
mapping = filtered_merge[["SCHOOL_NUMBER", "SCHOOL_NAME_y", "LOCATION"]]

associated_number = processed_reports.merge(mapping, left_on=["SCHOOL_NAME", "LOCATION"], right_on=["SCHOOL_NAME_y", "LOCATION"])
associated_number
# Out:
#      SCHOOL_NAME SCHOOL_TYPE  YEAR   LOCATION             ENROLMENT  \
# 0          Alpha      Public  2015    Burnaby  Gr 12 enrolment: 252
# 1          Alpha      Public  2016    Burnaby  Gr 12 enrolment: 252
# 2          Alpha      Public  2017    Burnaby  Gr 12 enrolment: 252
# 3          Alpha      Public  2018    Burnaby  Gr 12 enrolment: 252
# 4          Alpha      Public  2019    Burnaby  Gr 12 enrolment: 252
# ...          ...         ...   ...        ...                   ...
# 1170     Selkirk      Public  2015  Kimberley   Gr 12 enrolment: 68
# 1171     Selkirk      Public  2016  Kimberley   Gr 12 enrolment: 68
# 1172     Selkirk      Public  2017  Kimberley   Gr 12 enrolment: 68
# 1173     Selkirk      Public  2018  Kimberley   Gr 12 enrolment: 68
# 1174     Selkirk      Public  2019  Kimberley   Gr 12 enrolment: 68
#
#       PERCENT_ESL  PERCENT_SPECIAL_NEEDS  PERCENT_FRENCH_IMM  \
# 0             4.7                   10.7                12.5
# 1             4.7                   10.7                12.5
# 2             4.7                   10.7                12.5
# 3             4.7                   10.7                12.5
# 4             4.7                   10.7                12.5
# ...           ...                    ...                 ...
# 1170          0.0                   10.1                 0.0
# 1171          0.0                   10.1                 0.0
# 1172          0.0                   10.1                 0.0
# 1173          0.0                   10.1                 0.0
# 1174          0.0                   10.1                 0.0
#
#       AVERAGE_EXAM_MARK  PERCENT_EXAMS_FAILED  PERCENT_GRAD  PERCENT_DELAYED  \
# 0                  68.3                  11.5          94.8             15.0
# 1                  67.6                  11.7          91.4             13.6
# 2                  65.1                  16.2          87.7             17.7
# 3                  68.7                  10.0          95.6             10.2
# 4                  68.6                  13.4          97.2              6.7
# ...                 ...                   ...           ...              ...
# 1170               72.0                   4.2          98.6              6.5
# 1171               70.5                   7.7          96.5              5.3
# 1172               66.3                  10.3          96.4              7.2
# 1173               70.9                   7.0          98.7              4.7
# 1174               68.3                   7.4          98.4             10.7
#
#       OVERALL  SCHOOL_NUMBER SCHOOL_NAME_y
# 0         5.5        4141005         Alpha
# 1         5.3        4141005         Alpha
# 2         3.6        4141005         Alpha
# 3         5.4        4141005         Alpha
# 4         5.2        4141005         Alpha
# ...       ...            ...           ...
# 1170      7.2         603008       Selkirk
# 1171      6.8         603008       Selkirk
# 1172      5.5         603008       Selkirk
# 1173      6.2         603008       Selkirk
# 1174      6.3         603008       Selkirk
#
# [1175 rows x 15 columns]

# %%
verify_grouping = associated_number.groupby("SCHOOL_NUMBER")
# Each group should have 5 rows --> each corresponding to one year
invalid_groups = verify_grouping.filter(lambda x: len(x) != 5)
invalid_groups
# Out:
# Empty DataFrame
# Columns: [SCHOOL_NAME, SCHOOL_TYPE, YEAR, LOCATION, ENROLMENT, PERCENT_ESL, PERCENT_SPECIAL_NEEDS, PERCENT_FRENCH_IMM, AVERAGE_EXAM_MARK, PERCENT_EXAMS_FAILED, PERCENT_GRAD, PERCENT_DELAYED, OVERALL, SCHOOL_NUMBER, SCHOOL_NAME_y]
# Index: []

# %%
# Construct combined table
final_table = anglo_standard_secondary.merge(associated_number, on="SCHOOL_NUMBER").drop("SCHOOL_NAME_y", axis=1).rename(columns={"SCHOOL_NAME_x": "SCHOOL_NAME"})
final_table
# Out:
#      SCHOOL_YEAR  SCHOOL_NUMBER               SCHOOL_NAME  DISTRICT_NUMBER  \
# 0      2019/2020         502001     Mount Baker Secondary                5
# 1      2019/2020         502001     Mount Baker Secondary                5
# 2      2019/2020         502001     Mount Baker Secondary                5
# 3      2019/2020         502001     Mount Baker Secondary                5
# 4      2019/2020         502001     Mount Baker Secondary                5
# ...          ...            ...                       ...              ...
# 1170   2019/2020        9191024  Nechako Valley Secondary               91
# 1171   2019/2020        9191024  Nechako Valley Secondary               91
# 1172   2019/2020        9191024  Nechako Valley Secondary               91
# 1173   2019/2020        9191024  Nechako Valley Secondary               91
# 1174   2019/2020        9191024  Nechako Valley Secondary               91
#
#            DISTRICT_NAME PUBLIC_OR_INDEPENDENT STREET_ADDRESS  \
# 0     Southeast Kootenay                Public  1410 Baker St
# 1     Southeast Kootenay                Public  1410 Baker St
# 2     Southeast Kootenay                Public  1410 Baker St
# 3     Southeast Kootenay                Public  1410 Baker St
# 4     Southeast Kootenay                Public  1410 Baker St
# ...                  ...                   ...            ...
# 1170       Nechako Lakes                Public     PO Box 950
# 1171       Nechako Lakes                Public     PO Box 950
# 1172       Nechako Lakes                Public     PO Box 950
# 1173       Nechako Lakes                Public     PO Box 950
# 1174       Nechako Lakes                Public     PO Box 950
#
#      PHYSICAL_ADDRESS_CITY                              FACILTY_TYPE  \
# 0                Cranbrook  Standard School
# 1                Cranbrook  Standard School
# 2                Cranbrook  Standard School
# 3                Cranbrook  Standard School
# 4                Cranbrook  Standard School
# ...                    ...                                       ...
# 1170            Vanderhoof  Standard School
# 1171            Vanderhoof  Standard School
# 1172            Vanderhoof  Standard School
# 1173            Vanderhoof  Standard School
# 1174            Vanderhoof  Standard School
#
#      SCHOOL_EDUCATION_LEVEL  ...    LOCATION             ENROLMENT  \
# 0                 SECONDARY  ...   Cranbrook  Gr 12 enrolment: 257
# 1                 SECONDARY  ...   Cranbrook  Gr 12 enrolment: 257
# 2                 SECONDARY  ...   Cranbrook  Gr 12 enrolment: 257
# 3                 SECONDARY  ...   Cranbrook  Gr 12 enrolment: 257
# 4                 SECONDARY  ...   Cranbrook  Gr 12 enrolment: 257
# ...                     ...  ...         ...                   ...
# 1170   ELEMENTARY SECONDARY  ...  Vanderhoof   Gr 12 enrolment: 81
# 1171   ELEMENTARY SECONDARY  ...  Vanderhoof   Gr 12 enrolment: 81
# 1172   ELEMENTARY SECONDARY  ...  Vanderhoof   Gr 12 enrolment: 81
# 1173   ELEMENTARY SECONDARY  ...  Vanderhoof   Gr 12 enrolment: 81
# 1174   ELEMENTARY SECONDARY  ...  Vanderhoof   Gr 12 enrolment: 81
#
#      PERCENT_ESL PERCENT_SPECIAL_NEEDS  PERCENT_FRENCH_IMM  AVERAGE_EXAM_MARK  \
# 0            0.4                  14.4                 6.2               66.9
# 1            0.4                  14.4                 6.2               66.4
# 2            0.4                  14.4                 6.2               66.2
# 3            0.4                  14.4                 6.2               68.0
# 4            0.4                  14.4                 6.2               66.4
# ...          ...                   ...                 ...                ...
# 1170         0.0                  16.6                 4.1               66.8
# 1171         0.0                  16.6                 4.1               65.6
# 1172         0.0                  16.6                 4.1               67.0
# 1173         0.0                  16.6                 4.1               71.7
# 1174         0.0                  16.6                 4.1               66.5
#
#      PERCENT_EXAMS_FAILED  PERCENT_GRAD PERCENT_DELAYED OVERALL
# 0                     8.9          99.2             8.2     6.8
# 1                    10.6          96.8            16.9     6.1
# 2                     9.6          99.2             5.1     6.6
# 3                     8.7          97.8             9.7     6.7
# 4                     8.8          99.6             7.3     6.7
# ...                   ...           ...             ...     ...
# 1170                 11.1          97.6             9.1     5.8
# 1171                 13.2          96.2             8.3     5.1
# 1172                 12.6          98.0             3.3     6.4
# 1173                  1.6          98.4             7.8     6.9
# 1174                  8.2          98.7             2.8     6.4
#
# [1175 rows x 28 columns]

# %%
final_table.to_csv("combined_school_report.csv")
